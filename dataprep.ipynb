# %%
# !pip install -r req.txt
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 3.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting numpy
#   Downloading numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 2.3 MB/s eta 0:00:00
# Collecting Pillow
#   Downloading pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.6/486.6 kB 2.7 MB/s eta 0:00:002.6 MB/s eta 0:00:01
# Collecting transformers
#   Downloading transformers-4.57.1-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Collecting torch
#   Downloading torch-2.9.0-cp311-cp311-manylinux_2_28_x86_64.whl (899.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 1.3 MB/s eta 0:00:00m eta 0:00:010:00:14
# Collecting torchvision
#   Downloading torchvision-0.24.0-cp311-cp311-manylinux_2_28_x86_64.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 2.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 2.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 1.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting hdbscan
#   Downloading hdbscan-0.8.40-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 1.9 MB/s eta 0:00:000:00:010:00:01:01
# Collecting umap-learn
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 3.1 MB/s eta 0:00:00
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 3.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 3.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 4.1 MB/s eta 0:00:004.3 MB/s eta 0:00:01
# Collecting albumentations
#   Downloading albumentations-2.0.8-py3-none-any.whl (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.4/369.4 kB 3.4 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 3.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting fastapi
#   Downloading fastapi-0.119.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.1/107.1 kB 4.9 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 3.0 MB/s eta 0:00:000m eta -:--:--
# Collecting python-multipart
#   Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Collecting pydantic
#   Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.4/462.4 kB 5.4 MB/s eta 0:00:007.2 MB/s eta 0:00:01
# Collecting pinecone-client
#   Downloading pinecone_client-6.0.0-py3-none-any.whl (6.7 kB)
# Collecting langchain
#   Downloading langchain-1.0.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 26.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas->-r req.txt (line 2)) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.6/151.6 kB 6.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 4.8 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 4.8 MB/s eta 0:00:00
# Collecting scipy
#   Downloading scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 3.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting huggingface-hub>=0.20.0
#   Downloading huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 8.1 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: typing_extensions>=4.5.0 in ./.venv/lib/python3.11/site-packages (from sentence-transformers->-r req.txt (line 7)) (4.15.0)
# Collecting filelock
#   Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from transformers->-r req.txt (line 8)) (25.0)
# Collecting pyyaml>=5.1
#   Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.6/806.6 kB 7.1 MB/s eta 0:00:007.9 MB/s eta 0:00:01
# Collecting regex!=2019.12.17
#   Downloading regex-2025.9.18-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.0/799.0 kB 7.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 4.3 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.8/485.8 kB 7.3 MB/s eta 0:00:005.3 MB/s eta 0:00:01
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting networkx>=2.5.1
#   Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting fsspec>=0.8.5
#   Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 3.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 3.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nvidia-cuda-runtime-cu12==12.8.90
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 6.0 MB/s eta 0:00:005.5 MB/s eta 0:00:01
# Collecting nvidia-cuda-cupti-cu12==12.8.90
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 4.0 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Collecting nvidia-cudnn-cu12==9.10.2.21
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:00:14
# Collecting nvidia-cublas-cu12==12.8.4.1
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.0 MB/s eta 0:00:00m eta 0:00:010:00:07
# Collecting nvidia-cufft-cu12==11.3.3.83
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 2.8 MB/s eta 0:00:00m eta 0:00:010:00:02
# Collecting nvidia-curand-cu12==10.3.9.90
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nvidia-cusolver-cu12==11.7.3.90
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:00:02
# Collecting nvidia-cusparse-cu12==12.5.8.93
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:00:02
# Collecting nvidia-cusparselt-cu12==0.7.1
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 852.4 kB/s eta 0:00:00m eta 0:00:010:00:10
# Collecting nvidia-nccl-cu12==2.27.5
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:03
# Collecting nvidia-nvshmem-cu12==3.3.20
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 3.4 MB/s eta 0:00:00m eta 0:00:010:00:02
# Collecting nvidia-nvtx-cu12==12.8.90
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 6.6 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.8.93
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nvidia-cufile-cu12==1.13.1.3
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 4.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting triton==3.5.0
#   Downloading triton-3.5.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.4/170.4 MB 3.0 MB/s eta 0:00:00m eta 0:00:010:00:02
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 5.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting numba>=0.51.2
#   Downloading numba-0.62.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 4.0 MB/s eta 0:00:00m eta 0:00:010:01:01m
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.4 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (355 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.2/355.2 kB 5.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 3.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting pyparsing>=3
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 8.3 MB/s eta 0:00:00
# Collecting albucore==0.0.24
#   Downloading albucore-0.0.24-py3-none-any.whl (15 kB)
# Collecting opencv-python-headless>=4.9.0.80
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting stringzilla>=3.10.4
#   Downloading stringzilla-4.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (597 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 597.1/597.1 kB 3.1 MB/s eta 0:00:003.3 MB/s eta 0:00:01
# Collecting simsimd>=5.9.2
#   Downloading simsimd-6.5.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 2.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting numpy
#   Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 3.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting starlette<0.49.0,>=0.40.0
#   Downloading starlette-0.48.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 4.2 MB/s eta 0:00:00
# Collecting click>=7.0
#   Downloading click-8.3.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 6.4 MB/s eta 0:00:00
# Collecting h11>=0.8
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.4
#   Downloading pydantic_core-2.41.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 4.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Collecting langchain-core<2.0.0,>=1.0.0
#   Downloading langchain_core-1.0.0-py3-none-any.whl (467 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 3.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting langgraph<1.1.0,>=1.0.0
#   Downloading langgraph-1.0.0-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 3.9 MB/s eta 0:00:003.7 MB/s eta 0:00:01
# Collecting hf-xet<2.0.0,>=1.1.3
#   Downloading hf_xet-1.1.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 3.8 MB/s eta 0:00:003.8 MB/s eta 0:00:01
# Collecting jsonpatch<2.0.0,>=1.33.0
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<1.0.0,>=0.3.45
#   Downloading langsmith-0.4.37-py3-none-any.whl (396 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.1/396.1 kB 4.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0
#   Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting langgraph-checkpoint<3.0.0,>=2.1.0
#   Downloading langgraph_checkpoint-2.1.2-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 13.9 MB/s eta 0:00:00
# Collecting langgraph-prebuilt<1.1.0,>=1.0.0
#   Downloading langgraph_prebuilt-1.0.0-py3-none-any.whl (28 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 18.8 MB/s eta 0:00:00
# Collecting xxhash>=3.5.0
#   Downloading xxhash-3.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.9/193.9 kB 5.8 MB/s eta 0:00:009.3 MB/s eta 0:00:01
# Collecting llvmlite<0.46,>=0.45.0dev0
#   Downloading llvmlite-0.45.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 2.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r req.txt (line 2)) (1.17.0)
# Collecting anyio<5,>=3.6.2
#   Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 2.7 MB/s eta 0:00:002.8 MB/s eta 0:00:01
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting MarkupSafe>=2.0
#   Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting jsonpointer>=1.9
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting ormsgpack>=1.10.0
#   Downloading ormsgpack-1.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.4/207.4 kB 3.2 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting httpx>=0.25.2
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting orjson>=3.10.1
#   Downloading orjson-3.11.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 1.5 MB/s eta 0:00:001.0 MB/s eta 0:00:01
# Collecting requests-toolbelt>=1.0.0
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting zstandard>=0.23.0
#   Downloading zstandard-0.25.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 3.6 MB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Installing collected packages: simsimd, pytz, nvidia-cusparselt-cu12, mpmath, zstandard, xxhash, urllib3, tzdata, typing-inspection, triton, tqdm, threadpoolctl, tenacity, sympy, stringzilla, sniffio, safetensors, regex, pyyaml, python-multipart, pyparsing, pydantic-core, pinecone-plugin-interface, Pillow, ormsgpack, orjson, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, llvmlite, kiwisolver, jsonpointer, joblib, idna, hf-xet, h11, fsspec, fonttools, filelock, cycler, click, charset_normalizer, certifi, annotated-types, uvicorn, scipy, requests, pydantic, pinecone-client, pandas, opencv-python-headless, opencv-python, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, numba, jsonpatch, jinja2, httpcore, faiss-cpu, contourpy, anyio, starlette, scikit-learn, requests-toolbelt, nvidia-cusolver-cu12, matplotlib, lightgbm, huggingface-hub, httpx, albucore, torch, tokenizers, seaborn, pynndescent, langsmith, langgraph-sdk, hdbscan, fastapi, albumentations, umap-learn, transformers, torchvision, langchain-core, sentence-transformers, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
# Successfully installed MarkupSafe-3.0.3 Pillow-12.0.0 albucore-0.0.24 albumentations-2.0.8 annotated-types-0.7.0 anyio-4.11.0 certifi-2025.10.5 charset_normalizer-3.4.4 click-8.3.0 contourpy-1.3.3 cycler-0.12.1 faiss-cpu-1.12.0 fastapi-0.119.0 filelock-3.20.0 fonttools-4.60.1 fsspec-2025.9.0 h11-0.16.0 hdbscan-0.8.40 hf-xet-1.1.10 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-0.35.3 idna-3.11 jinja2-3.1.6 joblib-1.5.2 jsonpatch-1.33 jsonpointer-3.0.0 kiwisolver-1.4.9 langchain-1.0.0 langchain-core-1.0.0 langgraph-1.0.0 langgraph-checkpoint-2.1.2 langgraph-prebuilt-1.0.0 langgraph-sdk-0.2.9 langsmith-0.4.37 lightgbm-4.6.0 llvmlite-0.45.1 matplotlib-3.10.7 mpmath-1.3.0 networkx-3.5 numba-0.62.1 numpy-2.2.6 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 opencv-python-4.12.0.88 opencv-python-headless-4.12.0.88 orjson-3.11.3 ormsgpack-1.11.0 pandas-2.3.3 pinecone-client-6.0.0 pinecone-plugin-interface-0.0.7 pydantic-2.12.3 pydantic-core-2.41.4 pynndescent-0.5.13 pyparsing-3.2.5 python-multipart-0.0.20 pytz-2025.2 pyyaml-6.0.3 regex-2025.9.18 requests-2.32.5 requests-toolbelt-1.0.0 safetensors-0.6.2 scikit-learn-1.7.2 scipy-1.16.2 seaborn-0.13.2 sentence-transformers-5.1.1 simsimd-6.5.3 sniffio-1.3.1 starlette-0.48.0 stringzilla-4.2.1 sympy-1.14.0 tenacity-9.1.2 threadpoolctl-3.6.0 tokenizers-0.22.1 torch-2.9.0 torchvision-0.24.0 tqdm-4.67.1 transformers-4.57.1 triton-3.5.0 typing-inspection-0.4.2 tzdata-2025.2 umap-learn-0.5.9.post2 urllib3-2.5.0 uvicorn-0.38.0 xxhash-3.6.0 zstandard-0.25.0

# %%
# file: data_prep.py
# Run inside venv: python data_prep.py --csv products.csv
import argparse, json, os, re
from pathlib import Path
import pandas as pd
import requests
from tqdm import tqdm
from PIL import Image
from io import BytesIO

def clean_text(s):
    if pd.isna(s): return ""
    return re.sub(r"\s+", " ", str(s)).strip()

def normalize_row(row):
    row = dict(row)
    row['title'] = clean_text(row.get('title',''))
    row['brand'] = clean_text(row.get('brand',''))
    row['description'] = clean_text(row.get('description',''))
    p = row.get('price','')
    try:
        row['price'] = float(str(p).replace('$','').replace(',','').strip()) if str(p).strip() else None
    except:
        row['price'] = None
    cats = row.get('categories','')
    if pd.isna(cats) or cats=='':
        row['categories'] = []
    else:
        try:
            row['categories'] = list(eval(cats)) if isinstance(cats,str) and cats.strip().startswith('[') else [c.strip() for c in str(cats).split('|') if c.strip()]
        except:
            row['categories'] = [c.strip() for c in str(cats).split(',') if c.strip()]
    imgs = row.get('images','')
    if pd.isna(imgs) or imgs=='':
        row['images'] = []
    else:
        try:
            row['images'] = list(eval(imgs))
        except:
            row['images'] = [u.strip() for u in str(imgs).split(',') if u.strip()]
    # ensure uniq_id
    if not row.get('uniq_id'):
        row['uniq_id'] = f"uid_{abs(hash(row['title'])) % (10**9)}"
    return row

def download_and_thumb(url, dest_path, size=(512,512), timeout=10):
    try:
        r = requests.get(url.strip(), timeout=timeout)
        r.raise_for_status()
        img = Image.open(BytesIO(r.content)).convert('RGB')
        img.thumbnail(size)
        dest_path.parent.mkdir(parents=True, exist_ok=True)
        img.save(dest_path, format='JPEG', quality=85)
        return True
    except Exception:
        return False

def main(csv_path, out_dir="data_prep_output"):
    out = Path(out_dir)
    out.mkdir(parents=True, exist_ok=True)
    df = pd.read_csv(csv_path, engine='python')
    cleaned = df.apply(normalize_row, axis=1)
    cleaned_df = pd.DataFrame(list(cleaned))
    # save jsonl
    jsonl = out / "products_clean.jsonl"
    with open(jsonl, "w", encoding="utf-8") as f:
        for _, r in cleaned_df.iterrows():
            f.write(json.dumps(r.to_dict(), ensure_ascii=False) + "\n")
    # download images thumbnails
    img_dir = out / "images"
    for _, r in tqdm(cleaned_df.iterrows(), total=len(cleaned_df), desc="downloading images"):
        uid = r.get('uniq_id')
        for i, url in enumerate(r.get('images') or []):
            if not url: continue
            dest = img_dir / f"{uid}_{i}.jpg"
            if dest.exists(): continue
            download_and_thumb(url, dest)
    print("Saved:", jsonl, "Images at:", img_dir)


main(csv_path='products.csv')
# Out:
# downloading images: 100%|██████████| 312/312 [07:50<00:00,  1.51s/it]
# Saved: data_prep_output/products_clean.jsonl Images at: data_prep_output/images
